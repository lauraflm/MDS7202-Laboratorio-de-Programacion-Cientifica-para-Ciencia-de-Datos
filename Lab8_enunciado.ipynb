# %% [markdown]
# # **Laboratorio 8: Ready, Set, Deploy! 👩‍🚀👨‍🚀**
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Primavera 2025</strong></center>
#
# ### Cuerpo Docente:
#
# - Profesores: Diego Cortez, Gabriel Iturra
# - Auxiliares: Melanie Peña, Valentina Rojas
# - Ayudantes: Nicolás Cabello, Cristopher Urbina

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1:
# - Nombre de alumno 2:
#
# ### **Link de repositorio de GitHub:** [Insertar Repositorio](https://github.com/...../)

# %% [markdown]
# ## Temas a tratar
#
# - Entrenamiento y registro de modelos usando MLFlow.
# - Despliegue de modelo usando FastAPI
# - Containerización del proyecto usando Docker
#
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: Entregas Martes a las 23:59.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria, pero se recomienda **fuertemente** asistir.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquier material del curso que estimen conveniente.
#
# ### Objetivos principales del laboratorio
#
# - Generar una solución a un problema a partir de ML
# - Desplegar su solución usando MLFlow, FastAPI y Docker
#
# El laboratorio deberá ser desarrollado sin el uso indiscriminado de iteradores nativos de python (aka "for", "while"). La idea es que aprendan a exprimir al máximo las funciones optimizadas que nos entrega `pandas`, las cuales vale mencionar, son bastante más eficientes que los iteradores nativos sobre DataFrames.

# %% [markdown]
# # **Introducción**

# %% [markdown]
# <p align="center">
#   <img src="https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExODJnMHJzNzlkNmQweXoyY3ltbnZ2ZDlxY2c0aW5jcHNzeDNtOXBsdCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/AbPdhwsMgjMjax5reo/giphy.gif" width="400">
# </p>

# %% [markdown]
# Consumida en la tristeza el despido de Renacín, Smapina ha decaído en su desempeño, lo que se ha traducido en un irregular tratamiento del agua. Esto ha implicado una baja en la calidad del agua, llegando a haber algunos puntos de la comuna en la que el vital elemento no es apto para el consumo humano. Es por esto que la sanitaria pública de la municipalidad de Maipú se ha contactado con ustedes para que le entreguen una urgente solución a este problema (a la vez que dejan a Smapina, al igual que Renacín, sin trabajo 😔).
#
# El problema que la empresa le ha solicitado resolver es el de elaborar un sistema que les permita saber si el agua es potable o no. Para esto, la sanitaria les ha proveido una base de datos con la lectura de múltiples sensores IOT colocados en diversas cañerías, conductos y estanques. Estos sensores señalan nueve tipos de mediciones químicas y más una etiqueta elaborada en laboratorio que indica si el agua es potable o no el agua.
#
# La idea final es que puedan, en el caso que el agua no sea potable, dar un aviso inmediato para corregir el problema. Tenga en cuenta que parte del equipo docente vive en Maipú y su intoxicación podría implicar graves problemas para el cierre del curso.
#
# Atributos:
#
# 1. pH value
# 2. Hardness
# 3. Solids (Total dissolved solids - TDS)
# 4. Chloramines
# 5. Sulfate
# 6. Conductivity
# 7. Organic_carbon
# 8. Trihalomethanes
# 9. Turbidity
#
# Variable a predecir:
#
# 10. Potability (1 si es potable, 0 no potable)
#
# Descripción de cada atributo se pueden encontrar en el siguiente link: [dataset](https://www.kaggle.com/adityakadiwal/water-potability)

# %% [markdown]
# # **1. Optimización de modelos con Optuna + MLFlow (2.0 puntos)**
#
# El objetivo de esta sección es que ustedes puedan combinar Optuna con MLFlow para poder realizar la optimización de los hiperparámetros de sus modelos.
#
# Como aún no hemos hablado nada sobre `MLFlow` cabe preguntarse: **¡¿Qué !"#@ es `MLflow`?!**
#
# <p align="center">
#   <img src="https://media.tenor.com/eusgDKT4smQAAAAC/matthew-perry-chandler-bing.gif" width="400">
# </p>
#
# ## **MLFlow**
#
# `MLflow` es una plataforma de código abierto que simplifica la gestión y seguimiento de proyectos de aprendizaje automático. Con sus herramientas, los desarrolladores pueden organizar, rastrear y comparar experimentos, además de registrar modelos y controlar versiones.
#
# <p align="center">
#   <img src="https://spark.apache.org/images/mlflow-logo.png" width="350">
# </p>
#
# Si bien esta plataforma cuenta con un gran número de herramientas y funcionalidades, en este laboratorio trabajaremos con dos:
# 1. **Runs**: Registro que constituye la información guardada tras la ejecución de un entrenamiento. Cada `run` tiene su propio run_id, el cual sirve como identificador para el entrenamiento en sí mismo. Dentro de cada `run` podremos acceder a información como los hiperparámetros utilizados, las métricas obtenidas, las librerías requeridas y hasta nos permite descargar el modelo entrenado.
# 2. **Experiments**: Se utilizan para agrupar y organizar diferentes ejecuciones de modelos (`runs`). En ese sentido, un experimento puede agrupar 1 o más `runs`. De esta manera, es posible también registrar métricas, parámetros y archivos (artefactos) asociados a cada experimento.
#
# ### **Todo bien pero entonces, ¿cómo se usa en la práctica `MLflow`?**
#
# Es sencillo! Considerando un problema de machine learning genérico, podemos registrar la información relevante del entrenamiento ejecutando `mlflow.autolog()` antes entrenar nuestro modelo. Veamos este bonito ejemplo facilitado por los mismos creadores de `MLflow`:
#
# ```python
# #!pip install mlflow
# import mlflow # importar mlflow
#
# from sklearn.model_selection import train_test_split
# from sklearn.datasets import load_diabetes
# from sklearn.ensemble import RandomForestRegressor
#
# db = load_diabetes()
# X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)
#
# # Create and train models.
# rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
#
# mlflow.autolog() # registrar automáticamente información del entrenamiento
# with mlflow.start_run(): # delimita inicio y fin del run
#     # aquí comienza el run
#     rf.fit(X_train, y_train) # train the model
#     predictions = rf.predict(X_test) # Use the model to make predictions on the test dataset.
#     # aquí termina el run
# ```
#
# Si ustedes ejecutan el código anterior en sus máquinas locales (desde un jupyter notebook por ejemplo) se darán cuenta que en su directorio *root* se ha creado la carpeta `mlruns`. Esta carpeta lleva el tracking de todos los entrenamientos ejecutados desde el directorio root (importante: si se cambian de directorio y vuelven a ejecutar el código anterior, se creará otra carpeta y no tendrán acceso al entrenamiento anterior). Para visualizar estos entrenamientos, `MLflow` nos facilita hermosa interfaz visual a la que podemos acceder ejecutando:
#
# ```
# mlflow ui
# ```
#
# y luego pinchando en la ruta http://127.0.0.1:5000 que nos retorna la terminal. Veamos en vivo algunas de sus funcionalidades!
#
# <p align="center">
#   <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExZXVuM3A5MW1heDFpa21qbGlwN2pyc2VoNnZsMmRzODZxdnluemo2bCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/3o84sq21TxDH6PyYms/giphy.gif" width="400">
# </p>
#
# Les dejamos también algunos comandos útiles:
#
# - `mlflow.create_experiment("nombre_experimento")`: Les permite crear un nuevo experimento para agrupar entrenamientos
# - `mlflow.log_metric("nombre_métrica", métrica)`: Les permite registrar una métrica *custom* bajo el nombre de "nombre_métrica"

# %% [markdown]
# ## **1.1 Combinando Optuna + MLflow (2.0 puntos)**
#
# Ahora que tenemos conocimiento de ambas herramientas, intentemos ahora combinarlas para **más sabor**. El objetivo de este apartado es simple: automatizar la optimización de los parámetros de nuestros modelos usando `Optuna` y registrando de forma automática cada resultado en `MLFlow`.
#
# Considerando el objetivo planteado, se le pide completar la función `optimize_model`, la cual debe:
# - **Optimizar los hiperparámetros del modelo `XGBoost` usando `Optuna`.**
# - **Registrar cada entrenamiento en un experimento nuevo**, asegurándose de que la métrica `f1-score` se registre como `"valid_f1"`. No se deben guardar todos los experimentos en *Default*; en su lugar, cada `experiment` y `run` deben tener nombres interpretables, reconocibles y diferentes a los nombres por defecto (por ejemplo, para un run: "XGBoost con lr 0.1").
# - **Guardar los gráficos de Optuna** dentro de una carpeta de artefactos de Mlflow llamada `/plots`.
# - **Devolver el mejor modelo** usando la función `get_best_model` y serializarlo en el disco con `pickle.dump`. Luego, guardar el modelo en la carpeta `/models`.
# - **Guardar el código en `optimize.py`**. La ejecución de `python optimize.py` debería ejecutar la función `optimize_model`.
# - **Guardar las versiones de las librerías utilizadas** en el desarrollo.
# - **Respalde las configuraciones del modelo final y la importancia de las variables** en un gráfico dentro de la carpeta `/plots` creada anteriormente.
#
# *Hint: Le puede ser útil revisar los parámetros que recibe `mlflow.start_run`*
#
# ```python
# def get_best_model(experiment_id):
#     runs = mlflow.search_runs(experiment_id)
#     best_model_id = runs.sort_values("metrics.valid_f1")["run_id"].iloc[0]
#     best_model = mlflow.sklearn.load_model("runs:/" + best_model_id + "/model")
#
#     return best_model
# ```

# %%
def optimize_model():
  pass

# %% [markdown]
# # **2. FastAPI (2.0 puntos)**
#
# <div align="center">
#   <img src="https://media3.giphy.com/media/YQitE4YNQNahy/giphy-downsized-large.gif" width="500">
# </div>
#
# Con el modelo ya entrenado, la idea de esta sección es generar una API REST a la cual se le pueda hacer *requests* para así interactuar con su modelo. En particular, se le pide:
#
# - Guardar el código de esta sección en el archivo `main.py`. Note que ejecutar `python main.py` debería levantar el servidor en el puerto por defecto.
# - Defina `GET` con ruta tipo *home* que describa brevemente su modelo, el problema que intenta resolver, su entrada y salida.
# - Defina un `POST` a la ruta `/potabilidad/` donde utilice su mejor optimizado para predecir si una medición de agua es o no potable. Por ejemplo, una llamada de esta ruta con un *body*:
#
# ```json
# {
#    "ph":10.316400384553162,
#    "Hardness":217.2668424334475,
#    "Solids":10676.508475429378,
#    "Chloramines":3.445514571005745,
#    "Sulfate":397.7549459751925,
#    "Conductivity":492.20647361771086,
#    "Organic_carbon":12.812732207582542,
#    "Trihalomethanes":72.28192021570328,
#    "Turbidity":3.4073494284238364
# }
# ```
#
# Su servidor debería retornar una respuesta HTML con código 200 con:
#
#
# ```json
# {
#   "potabilidad": 0 # respuesta puede variar según el clasificador que entrenen
# }
# ```
#
# **`HINT:` Recuerde que puede utilizar [http://localhost:8000/docs](http://localhost:8000/docs) para hacer un `POST`.**

# %% [markdown]
# # **3. Docker (2 puntos)**

# %% [markdown]
# <div align="center">
#   <img src="https://miro.medium.com/v2/resize:fit:1400/1*9rafh2W0rbRJIKJzqYc8yA.gif" width="500">
# </div>

# %% [markdown]
# Tras el éxito de su aplicación web para generar la salida, Smapina le solicita que genere un contenedor para poder ejecutarla en cualquier computador de la empresa de agua potable.
#
# ## **3.1 Creación de Container (1 punto)**
#
# Cree un Dockerfile que use una imagen base de Python, copie los archivos del proyecto e instale las dependencias desde un `requirements.txt`. Con esto, construya y ejecute el contenedor Docker para la API configurada anteriormente. Entregue el código fuente (incluyendo `main.py`, `requirements.txt`, y `Dockerfile`) y la imagen Docker de la aplicación. Para la dockerización, asegúrese de cumplir con los siguientes puntos:
#
# 1. **Generar un archivo `.dockerignore`** que ignore carpetas y archivos innecesarios dentro del contenedor.
# 2. **Configurar un volumen** que permita la persistencia de los datos en una ruta local del computador.
# 3. **Exponer el puerto** para acceder a la ruta de la API sin tener que entrar al contenedor directamente.
# 4. **Incluir imágenes en el notebook** que muestren la ejecución del contenedor y los resultados obtenidos.
# 5. **Revisar y comentar los recursos utilizados por el contenedor**. Analice si los contenedores son livianos en términos de recursos.
#
# ## **3.2 Preguntas de Smapina (1 punto)**
# Tras haber experimentado con Docker, Smapina desea profundizar más en el tema y decide realizarle las siguientes consultas:
#
# - ¿Cómo se diferencia Docker de una máquina virtual (VM)?
# - ¿Cuál es la diferencia entre usar Docker y ejecutar la aplicación directamente en el sistema local?
# - ¿Cómo asegura Docker la consistencia entre diferentes entornos de desarrollo y producción?
# - ¿Cómo se gestionan los volúmenes en Docker para la persistencia de datos?
# - ¿Qué son Dockerfile y docker-compose.yml, y cuál es su propósito?

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas>=1.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: scikit-learn>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: xgboost>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (3.0.5)
# Requirement already satisfied: optuna>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (4.5.0)
# Requirement already satisfied: mlflow>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: matplotlib>=3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (3.9.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (0.13.2)
# Requirement already satisfied: plotly>=5.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (6.3.0)
# Requirement already satisfied: kaleido>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.5.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.5.0->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.5.0->-r requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.1.0->-r requirements.txt (line 3)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.1.0->-r requirements.txt (line 3)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.1.0->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: alembic>=1.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from optuna>=3.0.0->-r requirements.txt (line 5)) (1.13.3)
# Requirement already satisfied: colorlog in /opt/anaconda3/lib/python3.12/site-packages (from optuna>=3.0.0->-r requirements.txt (line 5)) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from optuna>=3.0.0->-r requirements.txt (line 5)) (24.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from optuna>=3.0.0->-r requirements.txt (line 5)) (2.0.34)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from optuna>=3.0.0->-r requirements.txt (line 5)) (4.66.5)
# Requirement already satisfied: PyYAML in /opt/anaconda3/lib/python3.12/site-packages (from optuna>=3.0.0->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: mlflow-skinny==3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow>=2.0.0->-r requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: mlflow-tracing==3.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow>=2.0.0->-r requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: Flask-CORS<7 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow>=2.0.0->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: Flask<4 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow>=2.0.0->-r requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow>=2.0.0->-r requirements.txt (line 6)) (43.0.0)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow>=2.0.0->-r requirements.txt (line 6)) (7.1.0)
# Requirement already satisfied: fastmcp<3,>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow>=2.0.0->-r requirements.txt (line 6)) (2.12.5)
# Requirement already satisfied: graphene<4 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow>=2.0.0->-r requirements.txt (line 6)) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow>=2.0.0->-r requirements.txt (line 6)) (23.0.0)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow>=2.0.0->-r requirements.txt (line 6)) (16.1.0)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.69.0)
# Requirement already satisfied: fastapi<1 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.116.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (7.0.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.38.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.38.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (6.33.0)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (2.12.3)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (4.14.1)
# Requirement already satisfied: uvicorn<1 in /opt/anaconda3/lib/python3.12/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.35.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 7)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 7)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5.0->-r requirements.txt (line 7)) (3.1.2)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/anaconda3/lib/python3.12/site-packages (from plotly>=5.0.0->-r requirements.txt (line 9)) (2.3.0)
# Requirement already satisfied: choreographer>=1.0.10 in /opt/anaconda3/lib/python3.12/site-packages (from kaleido>=0.2.1->-r requirements.txt (line 10)) (1.1.2)
# Requirement already satisfied: logistro>=1.0.8 in /opt/anaconda3/lib/python3.12/site-packages (from kaleido>=0.2.1->-r requirements.txt (line 10)) (2.0.0)
# Requirement already satisfied: orjson>=3.10.15 in /opt/anaconda3/lib/python3.12/site-packages (from kaleido>=0.2.1->-r requirements.txt (line 10)) (3.11.3)
# Requirement already satisfied: pytest-timeout>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from kaleido>=0.2.1->-r requirements.txt (line 10)) (2.4.0)
# Requirement already satisfied: Mako in /opt/anaconda3/lib/python3.12/site-packages (from alembic>=1.5.0->optuna>=3.0.0->-r requirements.txt (line 5)) (1.2.3)
# Requirement already satisfied: simplejson>=3.19.3 in /opt/anaconda3/lib/python3.12/site-packages (from choreographer>=1.0.10->kaleido>=0.2.1->-r requirements.txt (line 10)) (3.20.2)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.12/site-packages (from cryptography<47,>=43.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.17.1)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: authlib>=1.5.2 in /opt/anaconda3/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.6.5)
# Requirement already satisfied: cyclopts>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /opt/anaconda3/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: httpx>=0.28.1 in /opt/anaconda3/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: mcp<1.17.0,>=1.12.4 in /opt/anaconda3/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: openapi-core>=0.19.5 in /opt/anaconda3/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.19.5)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /opt/anaconda3/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: pyperclip>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.11.0)
# Requirement already satisfied: rich>=13.9.4 in /opt/anaconda3/lib/python3.12/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (14.2.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from Flask<4->mlflow>=2.0.0->-r requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from Flask<4->mlflow>=2.0.0->-r requirements.txt (line 6)) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from Flask<4->mlflow>=2.0.0->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /opt/anaconda3/lib/python3.12/site-packages (from Flask<4->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.6.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/anaconda3/lib/python3.12/site-packages (from graphene<4->mlflow>=2.0.0->-r requirements.txt (line 6)) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/anaconda3/lib/python3.12/site-packages (from graphene<4->mlflow>=2.0.0->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: pytest>=7.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from pytest-timeout>=2.4.0->kaleido>=0.2.1->-r requirements.txt (line 10)) (7.4.4)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.12->cryptography<47,>=43.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (2.21)
# Requirement already satisfied: attrs>=23.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (25.3.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /opt/anaconda3/lib/python3.12/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: google-auth~=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (2.41.1)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /opt/anaconda3/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.47.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (4.0.7)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (4.11.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.0.2)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from Jinja2>=3.1.2->Flask<4->mlflow>=2.0.0->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (2.6.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/anaconda3/lib/python3.12/site-packages (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: isodate in /opt/anaconda3/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.3.4)
# Requirement already satisfied: more-itertools in /opt/anaconda3/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (10.3.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: parse in /opt/anaconda3/lib/python3.12/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.20.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /opt/anaconda3/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.59b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.4.2)
# Requirement already satisfied: email-validator>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (2.3.0)
# Requirement already satisfied: iniconfig in /opt/anaconda3/lib/python3.12/site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->-r requirements.txt (line 10)) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/anaconda3/lib/python3.12/site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->-r requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (2.15.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio->httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (2.8.0)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (4.9.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.10.6)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.4.4)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.1.0)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/lib/python3.12/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (1.10.0)
# Requirement already satisfied: docutils in /opt/anaconda3/lib/python3.12/site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.0->mlflow>=2.0.0->-r requirements.txt (line 6)) (0.4.8)

# %%
# %pip install fastapi 'uvicorn[standard]' pydantic
# Out:
# Collecting fastapi
#   Using cached fastapi-0.119.1-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: pydantic in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.11.7)
# Requirement already satisfied: uvicorn[standard] in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.38.0)
# Collecting starlette<0.49.0,>=0.40.0 (from fastapi)
#   Using cached starlette-0.48.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastapi) (4.14.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from starlette<0.49.0,>=0.40.0->fastapi) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: click>=7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]) (8.2.1)
# Requirement already satisfied: h11>=0.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]) (0.16.0)
# Requirement already satisfied: httptools>=0.6.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]) (1.1.1)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]) (6.0.3)
# Requirement already satisfied: uvloop>=0.15.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn[standard]) (15.0.1)
# Using cached fastapi-0.119.1-py3-none-any.whl (108 kB)
# Using cached starlette-0.48.0-py3-none-any.whl (73 kB)
# Installing collected packages: starlette, fastapi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [fastapi]
# Successfully installed fastapi-0.119.1 starlette-0.48.0
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ![docker ps](imagenes/docker.png)

# %% [markdown]
# ![docker ps](imagenes/docs.png)

# %% [markdown]
# ![docker ps](imagenes/prediccion.png)

# %% [markdown]
# # Conclusión
#
# Éxito!
# <div align="center">
#   <img src="https://i.pinimg.com/originals/55/f5/fd/55f5fdc9455989f8caf7fca7f93bd96a.gif" width="500">
# </div>
